# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/age detection of actors/sample_submission.csv
# /kaggle/input/age detection of actors/test/test.csv
# /kaggle/input/age detection of actors/test/Test/8547.jpg
# /kaggle/input/age detection of actors/test/Test/22401.jpg
# /kaggle/input/age detection of actors/test/Test/7635.jpg
# /kaggle/input/age detection of actors/test/Test/11479.jpg
# /kaggle/input/age detection of actors/test/Test/6258.jpg
# /kaggle/input/age detection of actors/test/Test/18677.jpg
# /kaggle/input/age detection of actors/test/Test/11036.jpg
# /kaggle/input/age detection of actors/test/Test/9885.jpg
# /kaggle/input/age detection of actors/test/Test/3683.jpg
# /kaggle/input/age detection of actors/test/Test/17916.jpg
# /kaggle/input/age detection of actors/test/Test/15810.jpg
# /kaggle/input/age detection of actors/test/Test/5807.jpg
# /kaggle/input/age detection of actors/test/Test/12289.jpg
# /kaggle/input/age detection of actors/test/Test/26010.jpg
# /kaggle/input/age detection of actors/test/Test/9699.jpg
# /kaggle/input/age detection of actors/test/Test/10528.jpg
# /kaggle/input/age detection of actors/test/Test/16758.jpg
# /kaggle/input/age detection of actors/test/Test/15768.jpg
# /kaggle/input/age detection of actors/test/Test/11324.jpg
# /kaggle/input/age detection of actors/test/Test/5916.jpg
# /kaggle/input/age detection of actors/test/Test/3442.jpg
# /kaggle/input/age detection of actors/test/Test/33.jpg
# /kaggle/input/age detection of actors/test/Test/17021.jpg
# /kaggle/input/age detection of actors/test/Test/3469.jpg
# /kaggle/input/age detection of actors/test/Test/11097.jpg
# /kaggle/input/age detection of actors/test/Test/25315.jpg
# /kaggle/input/age detection of actors/test/Test/18778.jpg
# /kaggle/input/age detection of actors/test/Test/5832.jpg
# /kaggle/input/age detection of actors/test/Test/698.jpg
# /kaggle/input/age detection of actors/test/Test/16747.jpg
# /kaggle/input/age detection of actors/test/Test/20216.jpg
# /kaggle/input/age detection of actors/test/Test/7731.jpg
# /kaggle/input/age detection of actors/test/Test/5141.jpg
# /kaggle/input/age detection of actors/test/Test/16294.jpg
# /kaggle/input/age detection of actors/test/Test/18035.jpg
# /kaggle/input/age detection of actors/test/Test/5703.jpg
# /kaggle/input/age detection of actors/test/Test/15613.jpg
# /kaggle/input/age detection of actors/test/Test/23044.jpg
# /kaggle/input/age detection of actors/test/Test/5272.jpg
# /kaggle/input/age detection of actors/test/Test/19368.jpg
# /kaggle/input/age detection of actors/test/Test/25032.jpg
# /kaggle/input/age detection of actors/test/Test/7451.jpg
# /kaggle/input/age detection of actors/test/Test/2845.jpg
# /kaggle/input/age detection of actors/test/Test/2858.jpg
# /kaggle/input/age detection of actors/test/Test/16973.jpg
# /kaggle/input/age detection of actors/test/Test/11372.jpg
# /kaggle/input/age detection of actors/test/Test/9939.jpg
# /kaggle/input/age detection of actors/test/Test/10380.jpg
# /kaggle/input/age detection of actors/test/Test/12158.jpg
# /kaggle/input/age detection of actors/test/Test/24852.jpg
# /kaggle/input/age detection of actors/test/Test/18881.jpg
# /kaggle/input/age detection of actors/test/Test/17590.jpg
# /kaggle/input/age detection of actors/test/Test/21726.jpg
# /kaggle/input/age detection of actors/test/Test/19747.jpg
# /kaggle/input/age detection of actors/test/Test/3306.jpg
# /kaggle/input/age detection of actors/test/Test/13105.jpg
# /kaggle/input/age detection of actors/test/Test/20682.jpg
# /kaggle/input/age detection of actors/test/Test/11488.jpg
# /kaggle/input/age detection of actors/test/Test/1919.jpg
# /kaggle/input/age detection of actors/test/Test/5568.jpg
# /kaggle/input/age detection of actors/test/Test/18725.jpg
# /kaggle/input/age detection of actors/test/Test/1194.jpg
# /kaggle/input/age detection of actors/test/Test/8971.jpg
# /kaggle/input/age detection of actors/test/Test/1729.jpg
# /kaggle/input/age detection of actors/test/Test/1000.jpg
# /kaggle/input/age detection of actors/test/Test/24203.jpg
# /kaggle/input/age detection of actors/test/Test/713.jpg
# /kaggle/input/age detection of actors/test/Test/10005.jpg
# /kaggle/input/age detection of actors/test/Test/18525.jpg
# /kaggle/input/age detection of actors/test/Test/22323.jpg
# /kaggle/input/age detection of actors/test/Test/6323.jpg
# /kaggle/input/age detection of actors/test/Test/6838.jpg
# /kaggle/input/age detection of actors/test/Test/21511.jpg
# /kaggle/input/age detection of actors/test/Test/26215.jpg
# /kaggle/input/age detection of actors/test/Test/588.jpg
# /kaggle/input/age detection of actors/test/Test/428.jpg
# /kaggle/input/age detection of actors/test/Test/9440.jpg
# /kaggle/input/age detection of actors/test/Test/17045.jpg
# /kaggle/input/age detection of actors/test/Test/23098.jpg
# /kaggle/input/age detection of actors/test/Test/9237.jpg
# /kaggle/input/age detection of actors/test/Test/26464.jpg
# /kaggle/input/age detection of actors/test/Test/11186.jpg
# /kaggle/input/age detection of actors/test/Test/12921.jpg
# /kaggle/input/age detection of actors/test/Test/2949.jpg
# /kaggle/input/age detection of actors/test/Test/12835.jpg
# /kaggle/input/age detection of actors/test/Test/17118.jpg
# /kaggle/input/age detection of actors/test/Test/11181.jpg
# /kaggle/input/age detection of actors/test/Test/15953.jpg
# /kaggle/input/age detection of actors/test/Test/13099.jpg
# /kaggle/input/age detection of actors/test/Test/15239.jpg
# /kaggle/input/age detection of actors/test/Test/6558.jpg
# /kaggle/input/age detection of actors/test/Test/13233.jpg
# /kaggle/input/age detection of actors/test/Test/18048.jpg
# /kaggle/input/age detection of actors/test/Test/13506.jpg
# /kaggle/input/age detection of actors/test/Test/10072.jpg
# /kaggle/input/age detection of actors/test/Test/17837.jpg
# /kaggle/input/age detection of actors/test/Test/16979.jpg
# /kaggle/input/age detection of actors/test/Test/18883.jpg
# /kaggle/input/age detection of actors/test/Test/13211.jpg
# /kaggle/input/age detection of actors/test/Test/5095.jpg
# /kaggle/input/age detection of actors/test/Test/24438.jpg
# /kaggle/input/age detection of actors/test/Test/23162.jpg
# /kaggle/input/age detection of actors/test/Test/9479.jpg
# /kaggle/input/age detection of actors/test/Test/18928.jpg
# /kaggle/input/age detection of actors/test/Test/15813.jpg
# /kaggle/input/age detection of actors/test/Test/17733.jpg
# /kaggle/input/age detection of actors/test/Test/19638.jpg
# /kaggle/input/age detection of actors/test/Test/2353.jpg
# /kaggle/input/age detection of actors/test/Test/15743.jpg
# /kaggle/input/age detection of actors/test/Test/24102.jpg
# /kaggle/input/age detection of actors/test/Test/8348.jpg
# /kaggle/input/age detection of actors/test/Test/6970.jpg
# /kaggle/input/age detection of actors/test/Test/16629.jpg
# /kaggle/input/age detection of actors/test/Test/21837.jpg
# /kaggle/input/age detection of actors/test/Test/13812.jpg
# /kaggle/input/age detection of actors/test/Test/14385.jpg
# /kaggle/input/age detection of actors/test/Test/10370.jpg
# /kaggle/input/age detection of actors/test/Test/11149.jpg
# /kaggle/input/age detection of actors/test/Test/17439.jpg
# /kaggle/input/age detection of actors/test/Test/18151.jpg
# /kaggle/input/age detection of actors/test/Test/13242.jpg
# /kaggle/input/age detection of actors/test/Test/18557.jpg
# /kaggle/input/age detection of actors/test/Test/9823.jpg
# /kaggle/input/age detection of actors/test/Test/22120.jpg
# /kaggle/input/age detection of actors/test/Test/5481.jpg
# /kaggle/input/age detection of actors/test/Test/3961.jpg
# /kaggle/input/age detection of actors/test/Test/25237.jpg
# /kaggle/input/age detection of actors/test/Test/277.jpg
# /kaggle/input/age detection of actors/test/Test/11160.jpg
# /kaggle/input/age detection of actors/test/Test/23746.jpg
# /kaggle/input/age detection of actors/test/Test/4837.jpg
# /kaggle/input/age detection of actors/test/Test/13472.jpg
# /kaggle/input/age detection of actors/test/Test/2453.jpg
# /kaggle/input/age detection of actors/test/Test/12956.jpg
# /kaggle/input/age detection of actors/test/Test/25226.jpg
# /kaggle/input/age detection of actors/test/Test/12952.jpg
# /kaggle/input/age detection of actors/test/Test/1314.jpg
# /kaggle/input/age detection of actors/test/Test/6146.jpg
# /kaggle/input/age detection of actors/test/Test/244.jpg
# /kaggle/input/age detection of actors/test/Test/15934.jpg
# /kaggle/input/age detection of actors/test/Test/8911.jpg
# /kaggle/input/age detection of actors/test/Test/7894.jpg
# /kaggle/input/age detection of actors/test/Test/23763.jpg
# /kaggle/input/age detection of actors/test/Test/25866.jpg
# /kaggle/input/age detection of actors/test/Test/22637.jpg
# /kaggle/input/age detection of actors/test/Test/9680.jpg
# /kaggle/input/age detection of actors/test/Test/9821.jpg
# /kaggle/input/age detection of actors/test/Test/20310.jpg
# /kaggle/input/age detection of actors/test/Test/11951.jpg
# /kaggle/input/age detection of actors/test/Test/9960.jpg
# /kaggle/input/age detection of actors/test/Test/4726.jpg
# /kaggle/input/age detection of actors/test/Test/10486.jpg
# /kaggle/input/age detection of actors/test/Test/6372.jpg
# /kaggle/input/age detection of actors/test/Test/15345.jpg
# /kaggle/input/age detection of actors/test/Test/20995.jpg
# /kaggle/input/age detection of actors/test/Test/17212.jpg
# /kaggle/input/age detection of actors/test/Test/6728.jpg
# /kaggle/input/age detection of actors/test/Test/7498.jpg
# /kaggle/input/age detection of actors/test/Test/9876.jpg
# /kaggle/input/age detection of actors/test/Test/7529.jpg
# /kaggle/input/age detection of actors/test/Test/17208.jpg
# /kaggle/input/age detection of actors/test/Test/11294.jpg
# /kaggle/input/age detection of actors/test/Test/23930.jpg
# /kaggle/input/age detection of actors/test/Test/19053.jpg
# /kaggle/input/age detection of actors/test/Test/19330.jpg
# /kaggle/input/age detection of actors/test/Test/19767.jpg
# /kaggle/input/age detection of actors/test/Test/25137.jpg
# /kaggle/input/age detection of actors/test/Test/10688.jpg
# /kaggle/input/age detection of actors/test/Test/17935.jpg
# /kaggle/input/age detection of actors/test/Test/21291.jpg
# /kaggle/input/age detection of actors/test/Test/21204.jpg
# /kaggle/input/age detection of actors/test/Test/12883.jpg
# /kaggle/input/age detection of actors/test/Test/17537.jpg
# /kaggle/input/age detection of actors/test/Test/2519.jpg
# /kaggle/input/age detection of actors/test/Test/629.jpg
# /kaggle/input/age detection of actors/test/Test/22665.jpg
# /kaggle/input/age detection of actors/test/Test/375.jpg
# /kaggle/input/age detection of actors/test/Test/21264.jpg
# /kaggle/input/age detection of actors/test/Test/21306.jpg
# /kaggle/input/age detection of actors/test/Test/16955.jpg
# /kaggle/input/age detection of actors/test/Test/1481.jpg
# /kaggle/input/age detection of actors/test/Test/18759.jpg
# /kaggle/input/age detection of actors/test/Test/6236.jpg
# /kaggle/input/age detection of actors/test/Test/10391.jpg
# /kaggle/input/age detection of actors/test/Test/14243.jpg
# /kaggle/input/age detection of actors/test/Test/23627.jpg
# /kaggle/input/age detection of actors/test/Test/20765.jpg
# /kaggle/input/age detection of actors/test/Test/11624.jpg
# /kaggle/input/age detection of actors/test/Test/13552.jpg
# /kaggle/input/age detection of actors/test/Test/20342.jpg
# /kaggle/input/age detection of actors/test/Test/22338.jpg
# /kaggle/input/age detection of actors/test/Test/312.jpg
# /kaggle/input/age detection of actors/test/Test/19258.jpg
# /kaggle/input/age detection of actors/test/Test/13051.jpg
# /kaggle/input/age detection of actors/test/Test/10350.jpg
# /kaggle/input/age detection of actors/test/Test/196.jpg
# /kaggle/input/age detection of actors/test/Test/3614.jpg
# /kaggle/input/age detection of actors/test/Test/24801.jpg
# /kaggle/input/age detection of actors/test/Test/12237.jpg
# /kaggle/input/age detection of actors/test/Test/19711.jpg
# /kaggle/input/age detection of actors/test/Test/11050.jpg
# /kaggle/input/age detection of actors/test/Test/6438.jpg
# /kaggle/input/age detection of actors/test/Test/13491.jpg
# /kaggle/input/age detection of actors/test/Test/22421.jpg
# /kaggle/input/age detection of actors/test/Test/9621.jpg
# /kaggle/input/age detection of actors/test/Test/8597.jpg
# /kaggle/input/age detection of actors/test/Test/18981.jpg
# /kaggle/input/age detection of actors/test/Test/6413.jpg
# /kaggle/input/age detection of actors/test/Test/21883.jpg
# /kaggle/input/age detection of actors/test/Test/26370.jpg
# /kaggle/input/age detection of actors/test/Test/17625.jpg
# /kaggle/input/age detection of actors/test/Test/3851.jpg
# /kaggle/input/age detection of actors/test/Test/20193.jpg
# /kaggle/input/age detection of actors/test/Test/13136.jpg
# /kaggle/input/age detection of actors/test/Test/25460.jpg
# /kaggle/input/age detection of actors/test/Test/13218.jpg
# /kaggle/input/age detection of actors/test/Test/13975.jpg
# /kaggle/input/age detection of actors/test/Test/1236.jpg
# /kaggle/input/age detection of actors/test/Test/4486.jpg
# /kaggle/input/age detection of actors/test/Test/5960.jpg
# /kaggle/input/age detection of actors/test/Test/4244.jpg
# /kaggle/input/age detection of actors/test/Test/3396.jpg
# /kaggle/input/age detection of actors/test/Test/2484.jpg
# /kaggle/input/age detection of actors/test/Test/8169.jpg
# /kaggle/input/age detection of actors/test/Test/23529.jpg
# /kaggle/input/age detection of actors/test/Test/13471.jpg
# /kaggle/input/age detection of actors/test/Test/15095.jpg
# /kaggle/input/age detection of actors/test/Test/6574.jpg
# /kaggle/input/age detection of actors/test/Test/3310.jpg
# /kaggle/input/age detection of actors/test/Test/15831.jpg
# /kaggle/input/age detection of actors/test/Test/25030.jpg
# /kaggle/input/age detection of actors/test/Test/4359.jpg
# /kaggle/input/age detection of actors/test/Test/3340.jpg
# /kaggle/input/age detection of actors/test/Test/18196.jpg
# /kaggle/input/age detection of actors/test/Test/26023.jpg
# /kaggle/input/age detection of actors/test/Test/18133.jpg
# /kaggle/input/age detection of actors/test/Test/13048.jpg
# /kaggle/input/age detection of actors/test/Test/14106.jpg
# /kaggle/input/age detection of actors/test/Test/22051.jpg
# /kaggle/input/age detection of actors/test/Test/10523.jpg
# /kaggle/input/age detection of actors/test/Test/24476.jpg
# /kaggle/input/age detection of actors/test/Test/14257.jpg
# /kaggle/input/age detection of actors/test/Test/20136.jpg
# /kaggle/input/age detection of actors/test/Test/7067.jpg
# /kaggle/input/age detection of actors/test/Test/13610.jpg
# /kaggle/input/age detection of actors/test/Test/21393.jpg
# /kaggle/input/age detection of actors/test/Test/18777.jpg
# /kaggle/input/age detection of actors/test/Test/24466.jpg
# /kaggle/input/age detection of actors/test/Test/25320.jpg
# /kaggle/input/age detection of actors/test/Test/7734.jpg
# /kaggle/input/age detection of actors/test/Test/25076.jpg
# /kaggle/input/age detection of actors/test/Test/7306.jpg
# /kaggle/input/age detection of actors/test/Test/9993.jpg
# /kaggle/input/age detection of actors/test/Test/19458.jpg
# /kaggle/input/age detection of actors/test/Test/6308.jpg
# /kaggle/input/age detection of actors/test/Test/16558.jpg
# /kaggle/input/age detection of actors/test/Test/8918.jpg
# /kaggle/input/age detection of actors/test/Test/17516.jpg
# /kaggle/input/age detection of actors/test/Test/5809.jpg
# /kaggle/input/age detection of actors/test/Test/6517.jpg
# /kaggle/input/age detection of actors/test/Test/25647.jpg
# /kaggle/input/age detection of actors/test/Test/21707.jpg
# /kaggle/input/age detection of actors/test/Test/17377.jpg
# /kaggle/input/age detection of actors/test/Test/22132.jpg
# /kaggle/input/age detection of actors/test/Test/7610.jpg
# /kaggle/input/age detection of actors/test/Test/20378.jpg
# /kaggle/input/age detection of actors/test/Test/10194.jpg
# /kaggle/input/age detection of actors/test/Test/19868.jpg
# /kaggle/input/age detection of actors/test/Test/12415.jpg
# /kaggle/input/age detection of actors/test/Test/12705.jpg
# /kaggle/input/age detection of actors/test/Test/1196.jpg
# /kaggle/input/age detection of actors/test/Test/14622.jpg
# /kaggle/input/age detection of actors/test/Test/2930.jpg
# /kaggle/input/age detection of actors/test/Test/1177.jpg
# /kaggle/input/age detection of actors/test/Test/21378.jpg
# /kaggle/input/age detection of actors/test/Test/18943.jpg
# /kaggle/input/age detection of actors/test/Test/16594.jpg
# /kaggle/input/age detection of actors/test/Test/12257.jpg
# /kaggle/input/age detection of actors/test/Test/551.jpg
# /kaggle/input/age detection of actors/test/Test/8285.jpg
# /kaggle/input/age detection of actors/test/Test/23611.jpg
# /kaggle/input/age detection of actors/test/Test/5575.jpg
# /kaggle/input/age detection of actors/test/Test/14499.jpg
# /kaggle/input/age detection of actors/test/Test/21015.jpg
# /kaggle/input/age detection of actors/test/Test/22493.jpg
# /kaggle/input/age detection of actors/test/Test/4493.jpg
# /kaggle/input/age detection of actors/test/Test/1993.jpg
# /kaggle/input/age detection of actors/test/Test/11563.jpg
# /kaggle/input/age detection of actors/test/Test/25761.jpg
# /kaggle/input/age detection of actors/test/Test/8720.jpg
# /kaggle/input/age detection of actors/test/Test/21319.jpg
# /kaggle/input/age detection of actors/test/Test/3638.jpg
# /kaggle/input/age detection of actors/test/Test/1457.jpg
# /kaggle/input/age detection of actors/test/Test/22985.jpg
# /kaggle/input/age detection of actors/test/Test/9410.jpg
# /kaggle/input/age detection of actors/test/Test/9328.jpg
# /kaggle/input/age detection of actors/test/Test/12142.jpg
# /kaggle/input/age detection of actors/test/Test/24958.jpg
# /kaggle/input/age detection of actors/test/Test/8041.jpg
# /kaggle/input/age detection of actors/test/Test/25943.jpg
# /kaggle/input/age detection of actors/test/Test/18085.jpg
# /kaggle/input/age detection of actors/test/Test/6849.jpg
# /kaggle/input/age detection of actors/test/Test/1150.jpg
# /kaggle/input/age detection of actors/test/Test/4364.jpg
# /kaggle/input/age detection of actors/test/Test/17852.jpg
# /kaggle/input/age detection of actors/test/Test/23003.jpg
# /kaggle/input/age detection of actors/test/Test/13296.jpg
# /kaggle/input/age detection of actors/test/Test/9560.jpg
# /kaggle/input/age detection of actors/test/Test/10524.jpg
# /kaggle/input/age detection of actors/test/Test/23473.jpg
# /kaggle/input/age detection of actors/test/Test/3818.jpg
# /kaggle/input/age detection of actors/test/Test/24897.jpg
# /kaggle/input/age detection of actors/test/Test/8621.jpg
# /kaggle/input/age detection of actors/test/Test/24502.jpg
# /kaggle/input/age detection of actors/test/Test/6840.jpg
# /kaggle/input/age detection of actors/test/Test/3267.jpg
# /kaggle/input/age detection of actors/test/Test/7924.jpg
# /kaggle/input/age detection of actors/test/Test/25051.jpg
# /kaggle/input/age detection of actors/test/Test/13101.jpg
# /kaggle/input/age detection of actors/test/Test/10574.jpg
# /kaggle/input/age detection of actors/test/Test/23836.jpg
# /kaggle/input/age detection of actors/test/Test/24544.jpg
# /kaggle/input/age detection of actors/test/Test/17544.jpg
# /kaggle/input/age detection of actors/test/Test/23714.jpg
# /kaggle/input/age detection of actors/test/Test/23944.jpg
# /kaggle/input/age detection of actors/test/Test/2609.jpg
# /kaggle/input/age detection of actors/test/Test/15988.jpg
# /kaggle/input/age detection of actors/test/Test/21832.jpg
# /kaggle/input/age detection of actors/test/Test/1933.jpg
# /kaggle/input/age detection of actors/test/Test/24227.jpg
# /kaggle/input/age detection of actors/test/Test/12489.jpg
# /kaggle/input/age detection of actors/test/Test/22448.jpg
# /kaggle/input/age detection of actors/test/Test/26205.jpg
# /kaggle/input/age detection of actors/test/Test/20446.jpg
# /kaggle/input/age detection of actors/test/Test/15416.jpg
# /kaggle/input/age detection of actors/test/Test/10764.jpg
# /kaggle/input/age detection of actors/test/Test/21697.jpg
# /kaggle/input/age detection of actors/test/Test/2575.jpg
# /kaggle/input/age detection of actors/test/Test/22284.jpg
# /kaggle/input/age detection of actors/test/Test/12393.jpg
# /kaggle/input/age detection of actors/test/Test/17559.jpg
# /kaggle/input/age detection of actors/test/Test/10406.jpg
# /kaggle/input/age detection of actors/test/Test/170.jpg
# /kaggle/input/age detection of actors/test/Test/9880.jpg
# /kaggle/input/age detection of actors/test/Test/19664.jpg
# /kaggle/input/age detection of actors/test/Test/6239.jpg
# /kaggle/input/age detection of actors/test/Test/293.jpg
# /kaggle/input/age detection of actors/test/Test/9512.jpg
# /kaggle/input/age detection of actors/test/Test/7149.jpg
# /kaggle/input/age detection of actors/test/Test/19236.jpg
# /kaggle/input/age detection of actors/test/Test/9828.jpg
# /kaggle/input/age detection of actors/test/Test/3812.jpg
# /kaggle/input/age detection of actors/test/Test/5928.jpg
# /kaggle/input/age detection of actors/test/Test/24519.jpg
# /kaggle/input/age detection of actors/test/Test/21332.jpg
# /kaggle/input/age detection of actors/test/Test/20292.jpg
# /kaggle/input/age detection of actors/test/Test/16958.jpg
# /kaggle/input/age detection of actors/test/Test/4298.jpg
# /kaggle/input/age detection of actors/test/Test/9966.jpg
# /kaggle/input/age detection of actors/test/Test/1096.jpg
# /kaggle/input/age detection of actors/test/Test/25079.jpg
# /kaggle/input/age detection of actors/test/Test/4568.jpg
# /kaggle/input/age detection of actors/test/Test/18492.jpg
# /kaggle/input/age detection of actors/test/Test/8830.jpg
# /kaggle/input/age detection of actors/test/Test/15808.jpg
# /kaggle/input/age detection of actors/test/Test/9423.jpg
# /kaggle/input/age detection of actors/test/Test/22761.jpg
# /kaggle/input/age detection of actors/test/Test/165.jpg
# /kaggle/input/age detection of actors/test/Test/11643.jpg
# /kaggle/input/age detection of actors/test/Test/7818.jpg
# /kaggle/input/age detection of actors/test/Test/8252.jpg
# /kaggle/input/age detection of actors/test/Test/9528.jpg
# /kaggle/input/age detection of actors/test/Test/13507.jpg
# /kaggle/input/age detection of actors/test/Test/22673.jpg
# /kaggle/input/age detection of actors/test/Test/20786.jpg
# /kaggle/input/age detection of actors/test/Test/8590.jpg
# /kaggle/input/age detection of actors/test/Test/3691.jpg
# /kaggle/input/age detection of actors/test/Test/17224.jpg
# /kaggle/input/age detection of actors/test/Test/26213.jpg
# /kaggle/input/age detection of actors/test/Test/7757.jpg
# /kaggle/input/age detection of actors/test/Test/11762.jpg
# /kaggle/input/age detection of actors/test/Test/20556.jpg
# /kaggle/input/age detection of actors/test/Test/20227.jpg
# /kaggle/input/age detection of actors/test/Test/24018.jpg
# /kaggle/input/age detection of actors/test/Test/16650.jpg
# /kaggle/input/age detection of actors/test/Test/6939.jpg
# /kaggle/input/age detection of actors/test/Test/16642.jpg
# /kaggle/input/age detection of actors/test/Test/9540.jpg
# /kaggle/input/age detection of actors/test/Test/23323.jpg
# /kaggle/input/age detection of actors/test/Test/6815.jpg
# /kaggle/input/age detection of actors/test/Test/19899.jpg
# /kaggle/input/age detection of actors/test/Test/7276.jpg
# /kaggle/input/age detection of actors/test/Test/9170.jpg
# /kaggle/input/age detection of actors/test/Test/2758.jpg
# /kaggle/input/age detection of actors/test/Test/3423.jpg
# /kaggle/input/age detection of actors/test/Test/8038.jpg
# /kaggle/input/age detection of actors/test/Test/25404.jpg
# /kaggle/input/age detection of actors/test/Test/17408.jpg
# /kaggle/input/age detection of actors/test/Test/12904.jpg
# /kaggle/input/age detection of actors/test/Test/26380.jpg
# /kaggle/input/age detection of actors/test/Test/13897.jpg
# /kaggle/input/age detection of actors/test/Test/11370.jpg
# /kaggle/input/age detection of actors/test/Test/17517.jpg
# /kaggle/input/age detection of actors/test/Test/5888.jpg
# /kaggle/input/age detection of actors/test/Test/22358.jpg
# /kaggle/input/age detection of actors/test/Test/19199.jpg
# /kaggle/input/age detection of actors/test/Test/2997.jpg
# /kaggle/input/age detection of actors/test/Test/8824.jpg
# /kaggle/input/age detection of actors/test/Test/21474.jpg
# /kaggle/input/age detection of actors/test/Test/12858.jpg
# /kaggle/input/age detection of actors/test/Test/9884.jpg
# /kaggle/input/age detection of actors/test/Test/24549.jpg
# /kaggle/input/age detection of actors/test/Test/13066.jpg
# /kaggle/input/age detection of actors/test/Test/2262.jpg
# /kaggle/input/age detection of actors/test/Test/8142.jpg
# /kaggle/input/age detection of actors/test/Test/20859.jpg
# /kaggle/input/age detection of actors/test/Test/17686.jpg
# /kaggle/input/age detection of actors/test/Test/21262.jpg
# /kaggle/input/age detection of actors/test/Test/7390.jpg
# /kaggle/input/age detection of actors/test/Test/19769.jpg
# /kaggle/input/age detection of actors/test/Test/8305.jpg
# /kaggle/input/age detection of actors/test/Test/1817.jpg
# /kaggle/input/age detection of actors/test/Test/5423.jpg
# /kaggle/input/age detection of actors/test/Test/22199.jpg
# /kaggle/input/age detection of actors/test/Test/1189.jpg
# /kaggle/input/age detection of actors/test/Test/11809.jpg
# /kaggle/input/age detection of actors/test/Test/20913.jpg
# /kaggle/input/age detection of actors/test/Test/17564.jpg
# /kaggle/input/age detection of actors/test/Test/8459.jpg
# /kaggle/input/age detection of actors/test/Test/6497.jpg
# /kaggle/input/age detection of actors/test/Test/12529.jpg
# /kaggle/input/age detection of actors/test/Test/15067.jpg
# /kaggle/input/age detection of actors/test/Test/18421.jpg
# /kaggle/input/age detection of actors/test/Test/9928.jpg
# /kaggle/input/age detection of actors/test/Test/2779.jpg
# /kaggle/input/age detection of actors/test/Test/11731.jpg
# /kaggle/input/age detection of actors/test/Test/17266.jpg
# /kaggle/input/age detection of actors/test/Test/20331.jpg
# /kaggle/input/age detection of actors/test/Test/24331.jpg
# /kaggle/input/age detection of actors/test/Test/17401.jpg
# /kaggle/input/age detection of actors/test/Test/5753.jpg
# /kaggle/input/age detection of actors/test/Test/12245.jpg
# /kaggle/input/age detection of actors/test/Test/23758.jpg
# /kaggle/input/age detection of actors/test/Test/12534.jpg
# /kaggle/input/age detection of actors/test/Test/9605.jpg
# /kaggle/input/age detection of actors/test/Test/5719.jpg
# /kaggle/input/age detection of actors/test/Test/25049.jpg
# /kaggle/input/age detection of actors/test/Test/24082.jpg
# /kaggle/input/age detection of actors/test/Test/21168.jpg
# /kaggle/input/age detection of actors/test/Test/25445.jpg
# /kaggle/input/age detection of actors/test/Test/16592.jpg
# /kaggle/input/age detection of actors/test/Test/20235.jpg
# /kaggle/input/age detection of actors/test/Test/16017.jpg
# /kaggle/input/age detection of actors/test/Test/2147.jpg
# /kaggle/input/age detection of actors/test/Test/18417.jpg
# /kaggle/input/age detection of actors/test/Test/24583.jpg
# /kaggle/input/age detection of actors/test/Test/18551.jpg
# /kaggle/input/age detection of actors/test/Test/16556.jpg
# /kaggle/input/age detection of actors/test/Test/13819.jpg
# /kaggle/input/age detection of actors/test/Test/11512.jpg
# /kaggle/input/age detection of actors/test/Test/22869.jpg
# /kaggle/input/age detection of actors/test/Test/12169.jpg
# /kaggle/input/age detection of actors/test/Test/23175.jpg
# /kaggle/input/age detection of actors/test/Test/7102.jpg
# /kaggle/input/age detection of actors/test/Test/23976.jpg
# /kaggle/input/age detection of actors/test/Test/19536.jpg
# /kaggle/input/age detection of actors/test/Test/4941.jpg
# /kaggle/input/age detection of actors/test/Test/16841.jpg
# /kaggle/input/age detection of actors/test/Test/19306.jpg
# /kaggle/input/age detection of actors/test/Test/1304.jpg
# /kaggle/input/age detection of actors/test/Test/10730.jpg
# /kaggle/input/age detection of actors/test/Test/5610.jpg
# /kaggle/input/age detection of actors/test/Test/19974.jpg
# /kaggle/input/age detection of actors/test/Test/9654.jpg
# /kaggle/input/age detection of actors/test/Test/16500.jpg
# /kaggle/input/age detection of actors/test/Test/3587.jpg
# /kaggle/input/age detection of actors/test/Test/13382.jpg
# /kaggle/input/age detection of actors/test/Test/18240.jpg
# /kaggle/input/age detection of actors/test/Test/6401.jpg
# /kaggle/input/age detection of actors/test/Test/25989.jpg
# /kaggle/input/age detection of actors/test/Test/19738.jpg
# /kaggle/input/age detection of actors/test/Test/18894.jpg
# /kaggle/input/age detection of actors/test/Test/25256.jpg
# /kaggle/input/age detection of actors/test/Test/25375.jpg
# /kaggle/input/age detection of actors/test/Test/21133.jpg
# /kaggle/input/age detection of actors/test/Test/10369.jpg
# /kaggle/input/age detection of actors/test/Test/6452.jpg
# /kaggle/input/age detection of actors/test/Test/4012.jpg
# /kaggle/input/age detection of actors/test/Test/494.jpg
# /kaggle/input/age detection of actors/test/Test/26174.jpg
# /kaggle/input/age detection of actors/test/Test/15909.jpg
# /kaggle/input/age detection of actors/test/Test/5380.jpg
# /kaggle/input/age detection of actors/test/Test/24362.jpg
# /kaggle/input/age detection of actors/test/Test/13401.jpg
# /kaggle/input/age detection of actors/test/Test/6202.jpg
# /kaggle/input/age detection of actors/test/Test/10136.jpg
# /kaggle/input/age detection of actors/test/Test/10115.jpg
# /kaggle/input/age detection of actors/test/Test/15551.jpg
# /kaggle/input/age detection of actors/test/Test/13638.jpg
# /kaggle/input/age detection of actors/test/Test/4989.jpg
# /kaggle/input/age detection of actors/test/Test/13783.jpg
# /kaggle/input/age detection of actors/test/Test/23328.jpg
# /kaggle/input/age detection of actors/test/Test/21353.jpg
# /kaggle/input/age detection of actors/test/Test/24259.jpg
# /kaggle/input/age detection of actors/test/Test/10218.jpg
# /kaggle/input/age detection of actors/test/Test/26292.jpg
# /kaggle/input/age detection of actors/test/Test/11799.jpg
# /kaggle/input/age detection of actors/test/Test/10644.jpg
# /kaggle/input/age detection of actors/test/Test/16077.jpg
# /kaggle/input/age detection of actors/test/Test/15737.jpg
# /kaggle/input/age detection of actors/test/Test/12889.jpg
# /kaggle/input/age detection of actors/test/Test/5831.jpg
# /kaggle/input/age detection of actors/test/Test/6554.jpg
# /kaggle/input/age detection of actors/test/Test/13432.jpg
# /kaggle/input/age detection of actors/test/Test/18798.jpg
# /kaggle/input/age detection of actors/test/Test/19250.jpg
# /kaggle/input/age detection of actors/test/Test/5862.jpg
# /kaggle/input/age detection of actors/test/Test/6686.jpg
# /kaggle/input/age detection of actors/test/Test/14576.jpg
# /kaggle/input/age detection of actors/test/Test/19562.jpg
# /kaggle/input/age detection of actors/test/Test/9694.jpg
# /kaggle/input/age detection of actors/test/Test/10113.jpg
# /kaggle/input/age detection of actors/test/Test/16128.jpg
# /kaggle/input/age detection of actors/test/Test/22107.jpg
# /kaggle/input/age detection of actors/test/Test/5395.jpg
# /kaggle/input/age detection of actors/test/Test/734.jpg
# /kaggle/input/age detection of actors/test/Test/19089.jpg
# /kaggle/input/age detection of actors/test/Test/15485.jpg
# /kaggle/input/age detection of actors/test/Test/230.jpg
# /kaggle/input/age detection of actors/test/Test/22476.jpg
# /kaggle/input/age detection of actors/test/Test/3675.jpg
# /kaggle/input/age detection of actors/test/Test/15601.jpg
# /kaggle/input/age detection of actors/test/Test/12987.jpg
# /kaggle/input/age detection of actors/test/Test/7798.jpg
# /kaggle/input/age detection of actors/test/Test/12702.jpg
# /kaggle/input/age detection of actors/test/Test/25925.jpg
# /kaggle/input/age detection of actors/test/Test/5450.jpg
# /kaggle/input/age detection of actors/test/Test/4587.jpg
# /kaggle/input/age detection of actors/test/Test/4741.jpg
# /kaggle/input/age detection of actors/test/Test/14569.jpg
# /kaggle/input/age detection of actors/test/Test/24364.jpg
# /kaggle/input/age detection of actors/test/Test/9936.jpg
# /kaggle/input/age detection of actors/test/Test/12704.jpg
# /kaggle/input/age detection of actors/test/Test/3458.jpg
# /kaggle/input/age detection of actors/test/Test/12291.jpg
# /kaggle/input/age detection of actors/test/Test/19245.jpg
# /kaggle/input/age detection of actors/test/Test/16557.jpg
# /kaggle/input/age detection of actors/test/Test/16392.jpg
# /kaggle/input/age detection of actors/test/Test/17636.jpg
# /kaggle/input/age detection of actors/test/Test/8473.jpg
# /kaggle/input/age detection of actors/test/Test/22986.jpg
# /kaggle/input/age detection of actors/test/Test/13283.jpg
# /kaggle/input/age detection of actors/test/Test/6358.jpg
# /kaggle/input/age detection of actors/test/Test/5379.jpg
# /kaggle/input/age detection of actors/test/Test/4649.jpg
# /kaggle/input/age detection of actors/test/Test/9163.jpg
# /kaggle/input/age detection of actors/test/Test/3706.jpg
# /kaggle/input/age detection of actors/test/Test/11508.jpg
# /kaggle/input/age detection of actors/test/Test/5418.jpg
# /kaggle/input/age detection of actors/test/Test/10014.jpg
# /kaggle/input/age detection of actors/test/Test/19474.jpg
# /kaggle/input/age detection of actors/test/Test/6842.jpg
# /kaggle/input/age detection of actors/test/Test/9116.jpg
# /kaggle/input/age detection of actors/test/Test/22307.jpg
# /kaggle/input/age detection of actors/test/Test/21053.jpg
# /kaggle/input/age detection of actors/test/Test/5453.jpg
# /kaggle/input/age detection of actors/test/Test/14898.jpg
# /kaggle/input/age detection of actors/test/Test/5560.jpg
# /kaggle/input/age detection of actors/test/Test/19212.jpg
# /kaggle/input/age detection of actors/test/Test/25039.jpg
# /kaggle/input/age detection of actors/test/Test/22562.jpg
# /kaggle/input/age detection of actors/test/Test/24664.jpg
# /kaggle/input/age detection of actors/test/Test/9648.jpg
# /kaggle/input/age detection of actors/test/Test/3032.jpg
# /kaggle/input/age detection of actors/test/Test/4081.jpg
# /kaggle/input/age detection of actors/test/Test/12202.jpg
# /kaggle/input/age detection of actors/test/Test/23938.jpg
# /kaggle/input/age detection of actors/test/Test/26093.jpg
# /kaggle/input/age detection of actors/test/Test/8587.jpg
# /kaggle/input/age detection of actors/test/Test/24705.jpg
# /kaggle/input/age detection of actors/test/Test/12633.jpg
# /kaggle/input/age detection of actors/test/Test/22072.jpg
# /kaggle/input/age detection of actors/test/Test/16091.jpg
# /kaggle/input/age detection of actors/test/Test/12432.jpg
# /kaggle/input/age detection of actors/test/Test/8071.jpg
# /kaggle/input/age detection of actors/test/Test/24611.jpg
# /kaggle/input/age detection of actors/test/Test/4119.jpg
# /kaggle/input/age detection of actors/test/Test/16975.jpg
# /kaggle/input/age detection of actors/test/Test/18767.jpg
# /kaggle/input/age detection of actors/test/Test/5375.jpg
# /kaggle/input/age detection of actors/test/Test/17506.jpg
# /kaggle/input/age detection of actors/test/Test/15177.jpg
# /kaggle/input/age detection of actors/test/Test/15188.jpg
# /kaggle/input/age detection of actors/test/Test/23045.jpg
# /kaggle/input/age detection of actors/test/Test/18935.jpg
# /kaggle/input/age detection of actors/test/Test/3767.jpg
# /kaggle/input/age detection of actors/test/Test/6920.jpg
# /kaggle/input/age detection of actors/test/Test/25554.jpg
# /kaggle/input/age detection of actors/test/Test/18729.jpg
# /kaggle/input/age detection of actors/test/Test/539.jpg
# /kaggle/input/age detection of actors/test/Test/9878.jpg
# /kaggle/input/age detection of actors/test/Test/25403.jpg
# /kaggle/input/age detection of actors/test/Test/11120.jpg
# /kaggle/input/age detection of actors/test/Test/15036.jpg
# /kaggle/input/age detection of actors/test/Test/22326.jpg
# /kaggle/input/age detection of actors/test/Test/11607.jpg
# /kaggle/input/age detection of actors/test/Test/24190.jpg
# /kaggle/input/age detection of actors/test/Test/15992.jpg
# /kaggle/input/age detection of actors/test/Test/4326.jpg
# /kaggle/input/age detection of actors/test/Test/14700.jpg
# /kaggle/input/age detection of actors/test/Test/7114.jpg
# /kaggle/input/age detection of actors/test/Test/13886.jpg
# /kaggle/input/age detection of actors/test/Test/1605.jpg
# /kaggle/input/age detection of actors/test/Test/19405.jpg
# /kaggle/input/age detection of actors/test/Test/12845.jpg
# /kaggle/input/age detection of actors/test/Test/17714.jpg
# /kaggle/input/age detection of actors/test/Test/24493.jpg
# /kaggle/input/age detection of actors/test/Test/9031.jpg
# /kaggle/input/age detection of actors/test/Test/4873.jpg
# /kaggle/input/age detection of actors/test/Test/14337.jpg
# /kaggle/input/age detection of actors/test/Test/974.jpg
# /kaggle/input/age detection of actors/test/Test/4920.jpg
# /kaggle/input/age detection of actors/test/Test/17165.jpg
# /kaggle/input/age detection of actors/test/Test/6851.jpg
# /kaggle/input/age detection of actors/test/Test/19024.jpg
# /kaggle/input/age detection of actors/test/Test/3978.jpg
# /kaggle/input/age detection of actors/test/Test/10648.jpg
# /kaggle/input/age detection of actors/test/Test/7219.jpg
# /kaggle/input/age detection of actors/test/Test/1672.jpg
# /kaggle/input/age detection of actors/test/Test/19302.jpg
# /kaggle/input/age detection of actors/test/Test/19403.jpg
# /kaggle/input/age detection of actors/test/Test/9784.jpg
# /kaggle/input/age detection of actors/test/Test/1226.jpg
# /kaggle/input/age detection of actors/test/Test/22514.jpg
# /kaggle/input/age detection of actors/test/Test/6402.jpg
# /kaggle/input/age detection of actors/test/Test/5801.jpg
# /kaggle/input/age detection of actors/test/Test/26197.jpg
# /kaggle/input/age detection of actors/test/Test/4101.jpg
# /kaggle/input/age detection of actors/test/Test/3627.jpg
# /kaggle/input/age detection of actors/test/Test/24809.jpg
# /kaggle/input/age detection of actors/test/Test/3235.jpg
# /kaggle/input/age detection of actors/test/Test/24698.jpg
# /kaggle/input/age detection of actors/test/Test/15916.jpg
# /kaggle/input/age detection of actors/test/Test/12910.jpg
# /kaggle/input/age detection of actors/test/Test/2053.jpg
# /kaggle/input/age detection of actors/test/Test/1701.jpg
# /kaggle/input/age detection of actors/test/Test/6858.jpg
# /kaggle/input/age detection of actors/test/Test/4063.jpg
# /kaggle/input/age detection of actors/test/Test/12634.jpg
# /kaggle/input/age detection of actors/test/Test/1072.jpg
# /kaggle/input/age detection of actors/test/Test/26297.jpg
# /kaggle/input/age detection of actors/test/Test/3791.jpg
# /kaggle/input/age detection of actors/test/Test/25080.jpg
# /kaggle/input/age detection of actors/test/Test/7384.jpg
# /kaggle/input/age detection of actors/test/Test/4175.jpg
# /kaggle/input/age detection of actors/test/Test/18189.jpg
# /kaggle/input/age detection of actors/test/Test/13645.jpg
# /kaggle/input/age detection of actors/test/Test/11432.jpg
# /kaggle/input/age detection of actors/test/Test/22654.jpg
# /kaggle/input/age detection of actors/test/Test/19217.jpg
# /kaggle/input/age detection of actors/test/Test/8543.jpg
# /kaggle/input/age detection of actors/test/Test/26282.jpg
# /kaggle/input/age detection of actors/test/Test/13553.jpg
# /kaggle/input/age detection of actors/test/Test/25008.jpg
# /kaggle/input/age detection of actors/test/Test/18919.jpg
# /kaggle/input/age detection of actors/test/Test/5122.jpg
# /kaggle/input/age detection of actors/test/Test/24811.jpg
# /kaggle/input/age detection of actors/test/Test/7909.jpg
# /kaggle/input/age detection of actors/test/Test/25295.jpg
# /kaggle/input/age detection of actors/test/Test/25409.jpg
# /kaggle/input/age detection of actors/test/Test/4626.jpg
# /kaggle/input/age detection of actors/test/Test/1231.jpg
# /kaggle/input/age detection of actors/test/Test/15534.jpg
# /kaggle/input/age detection of actors/test/Test/23819.jpg
# /kaggle/input/age detection of actors/test/Test/4743.jpg
# /kaggle/input/age detection of actors/test/Test/19865.jpg
# /kaggle/input/age detection of actors/test/Test/16465.jpg
# /kaggle/input/age detection of actors/test/Test/23625.jpg
# /kaggle/input/age detection of actors/test/Test/13424.jpg
# /kaggle/input/age detection of actors/test/Test/11163.jpg
# /kaggle/input/age detection of actors/test/Test/21326.jpg
# /kaggle/input/age detection of actors/test/Test/18721.jpg
# /kaggle/input/age detection of actors/test/Test/12524.jpg
# /kaggle/input/age detection of actors/test/Test/9485.jpg
# /kaggle/input/age detection of actors/test/Test/11167.jpg
# /kaggle/input/age detection of actors/test/Test/22686.jpg
# /kaggle/input/age detection of actors/test/Test/25317.jpg
# /kaggle/input/age detection of actors/test/Test/7916.jpg
# /kaggle/input/age detection of actors/test/Test/6556.jpg
# /kaggle/input/age detection of actors/test/Test/23983.jpg
# /kaggle/input/age detection of actors/test/Test/26538.jpg
# /kaggle/input/age detection of actors/test/Test/10460.jpg
# /kaggle/input/age detection of actors/test/Test/8230.jpg
# /kaggle/input/age detection of actors/test/Test/5834.jpg
# /kaggle/input/age detection of actors/test/Test/21355.jpg
# /kaggle/input/age detection of actors/test/Test/3581.jpg
# /kaggle/input/age detection of actors/test/Test/22695.jpg
# /kaggle/input/age detection of actors/test/Test/23679.jpg
# /kaggle/input/age detection of actors/test/Test/7865.jpg
# /kaggle/input/age detection of actors/test/Test/18083.jpg
# /kaggle/input/age detection of actors/test/Test/1731.jpg
# /kaggle/input/age detection of actors/test/Test/23148.jpg
# /kaggle/input/age detection of actors/test/Test/6379.jpg
# /kaggle/input/age detection of actors/test/Test/5497.jpg
# /kaggle/input/age detection of actors/test/Test/25346.jpg
# /kaggle/input/age detection of actors/test/Test/13096.jpg
# /kaggle/input/age detection of actors/test/Test/6755.jpg
# /kaggle/input/age detection of actors/test/Test/19989.jpg
# /kaggle/input/age detection of actors/test/Test/4668.jpg
# /kaggle/input/age detection of actors/test/Test/17571.jpg
# /kaggle/input/age detection of actors/test/Test/21271.jpg
# /kaggle/input/age detection of actors/test/Test/13586.jpg
# /kaggle/input/age detection of actors/test/Test/6794.jpg
# /kaggle/input/age detection of actors/test/Test/6264.jpg
# /kaggle/input/age detection of actors/test/Test/20462.jpg
# /kaggle/input/age detection of actors/test/Test/26540.jpg
# /kaggle/input/age detection of actors/test/Test/19932.jpg
# /kaggle/input/age detection of actors/test/Test/18372.jpg
# /kaggle/input/age detection of actors/test/Test/16552.jpg
# /kaggle/input/age detection of actors/test/Test/3853.jpg
# /kaggle/input/age detection of actors/test/Test/12932.jpg
# /kaggle/input/age detection of actors/test/Test/6934.jpg
# /kaggle/input/age detection of actors/test/Test/24052.jpg
# /kaggle/input/age detection of actors/test/Test/10866.jpg
# /kaggle/input/age detection of actors/test/Test/22725.jpg
# /kaggle/input/age detection of actors/test/Test/7180.jpg
# /kaggle/input/age detection of actors/test/Test/13461.jpg
# /kaggle/input/age detection of actors/test/Test/14227.jpg
# /kaggle/input/age detection of actors/test/Test/565.jpg
# /kaggle/input/age detection of actors/test/Test/11283.jpg
# /kaggle/input/age detection of actors/test/Test/26088.jpg
# /kaggle/input/age detection of actors/test/Test/17479.jpg
# /kaggle/input/age detection of actors/test/Test/9666.jpg
# /kaggle/input/age detection of actors/test/Test/16009.jpg
# /kaggle/input/age detection of actors/test/Test/12621.jpg
# /kaggle/input/age detection of actors/test/Test/12700.jpg
# /kaggle/input/age detection of actors/test/Test/20793.jpg
# /kaggle/input/age detection of actors/test/Test/11733.jpg
# /kaggle/input/age detection of actors/test/Test/12417.jpg
# /kaggle/input/age detection of actors/test/Test/2290.jpg
# /kaggle/input/age detection of actors/test/Test/26362.jpg
# /kaggle/input/age detection of actors/test/Test/6599.jpg
# /kaggle/input/age detection of actors/test/Test/280.jpg
# /kaggle/input/age detection of actors/test/Test/22116.jpg
# /kaggle/input/age detection of actors/test/Test/16838.jpg
# /kaggle/input/age detection of actors/test/Test/13787.jpg
# /kaggle/input/age detection of actors/test/Test/8808.jpg
# /kaggle/input/age detection of actors/test/Test/6355.jpg
# /kaggle/input/age detection of actors/test/Test/1785.jpg
# /kaggle/input/age detection of actors/test/Test/12654.jpg
# /kaggle/input/age detection of actors/test/Test/5484.jpg
# /kaggle/input/age detection of actors/test/Test/376.jpg
# /kaggle/input/age detection of actors/test/Test/2706.jpg
# /kaggle/input/age detection of actors/test/Test/24486.jpg
# /kaggle/input/age detection of actors/test/Test/14008.jpg
# /kaggle/input/age detection of actors/test/Test/17409.jpg
# /kaggle/input/age detection of actors/test/Test/9105.jpg
# /kaggle/input/age detection of actors/test/Test/6444.jpg
# /kaggle/input/age detection of actors/test/Test/22619.jpg
# /kaggle/input/age detection of actors/test/Test/21786.jpg
# /kaggle/input/age detection of actors/test/Test/13741.jpg
# /kaggle/input/age detection of actors/test/Test/17236.jpg
# /kaggle/input/age detection of actors/test/Test/26163.jpg
# /kaggle/input/age detection of actors/test/Test/6677.jpg
# /kaggle/input/age detection of actors/test/Test/20395.jpg
# /kaggle/input/age detection of actors/test/Test/8338.jpg
# /kaggle/input/age detection of actors/test/Test/18173.jpg
# /kaggle/input/age detection of actors/test/Test/25157.jpg
# /kaggle/input/age detection of actors/test/Test/13063.jpg
# /kaggle/input/age detection of actors/test/Test/24518.jpg
# /kaggle/input/age detection of actors/test/Test/19592.jpg
# /kaggle/input/age detection of actors/test/Test/2470.jpg
# /kaggle/input/age detection of actors/test/Test/25550.jpg
# /kaggle/input/age detection of actors/test/Test/11612.jpg
# /kaggle/input/age detection of actors/test/Test/15140.jpg
# /kaggle/input/age detection of actors/test/Test/7197.jpg
# /kaggle/input/age detection of actors/test/Test/6415.jpg
# /kaggle/input/age detection of actors/test/Test/3935.jpg
# /kaggle/input/age detection of actors/test/Test/411.jpg
# /kaggle/input/age detection of actors/test/Test/7332.jpg
# /kaggle/input/age detection of actors/test/Test/21414.jpg
# /kaggle/input/age detection of actors/test/Test/21452.jpg
# /kaggle/input/age detection of actors/test/Test/21872.jpg
# /kaggle/input/age detection of actors/test/Test/12522.jpg
# /kaggle/input/age detection of actors/test/Test/15501.jpg
# /kaggle/input/age detection of actors/test/Test/2975.jpg
# /kaggle/input/age detection of actors/test/Test/500.jpg
# /kaggle/input/age detection of actors/test/Test/10590.jpg
# /kaggle/input/age detection of actors/test/Test/22615.jpg
# /kaggle/input/age detection of actors/test/Test/12044.jpg
# /kaggle/input/age detection of actors/test/Test/20906.jpg
# /kaggle/input/age detection of actors/test/Test/23928.jpg
# /kaggle/input/age detection of actors/test/Test/12532.jpg
# /kaggle/input/age detection of actors/test/Test/14977.jpg
# /kaggle/input/age detection of actors/test/Test/8000.jpg
# /kaggle/input/age detection of actors/test/Test/5135.jpg
# /kaggle/input/age detection of actors/test/Test/3558.jpg
# /kaggle/input/age detection of actors/test/Test/12703.jpg
# /kaggle/input/age detection of actors/test/Test/11550.jpg
# /kaggle/input/age detection of actors/test/Test/15107.jpg
# /kaggle/input/age detection of actors/test/Test/20103.jpg
# /kaggle/input/age detection of actors/test/Test/5353.jpg
# /kaggle/input/age detection of actors/test/Test/18401.jpg
# /kaggle/input/age detection of actors/test/Test/26045.jpg
# /kaggle/input/age detection of actors/test/Test/23475.jpg
# /kaggle/input/age detection of actors/test/Test/19973.jpg
# /kaggle/input/age detection of actors/test/Test/7376.jpg
# /kaggle/input/age detection of actors/test/Test/25721.jpg
# /kaggle/input/age detection of actors/test/Test/23979.jpg
# /kaggle/input/age detection of actors/test/Test/17423.jpg
# /kaggle/input/age detection of actors/test/Test/23188.jpg
# /kaggle/input/age detection of actors/test/Test/11538.jpg
# /kaggle/input/age detection of actors/test/Test/19770.jpg
# /kaggle/input/age detection of actors/test/Test/17324.jpg
# /kaggle/input/age detection of actors/test/Test/22276.jpg
# /kaggle/input/age detection of actors/test/Test/14291.jpg
# /kaggle/input/age detection of actors/test/Test/13003.jpg
# /kaggle/input/age detection of actors/test/Test/21035.jpg
# /kaggle/input/age detection of actors/test/Test/20261.jpg
# /kaggle/input/age detection of actors/test/Test/9469.jpg
# /kaggle/input/age detection of actors/test/Test/3837.jpg
# /kaggle/input/age detection of actors/test/Test/200.jpg
# /kaggle/input/age detection of actors/test/Test/22691.jpg
# /kaggle/input/age detection of actors/test/Test/12582.jpg
# /kaggle/input/age detection of actors/test/Test/20897.jpg
# /kaggle/input/age detection of actors/test/Test/3921.jpg
# /kaggle/input/age detection of actors/test/Test/14503.jpg
# /kaggle/input/age detection of actors/test/Test/13682.jpg
# /kaggle/input/age detection of actors/test/Test/12665.jpg
# /kaggle/input/age detection of actors/test/Test/23795.jpg
# /kaggle/input/age detection of actors/test/Test/4006.jpg
# ...
# /kaggle/input/age detection of actors/train/Train/20204.jpg
# /kaggle/input/age detection of actors/train/Train/21140.jpg
# /kaggle/input/age detection of actors/train/Train/12658.jpg
# /kaggle/input/age detection of actors/train/Train/17928.jpg
# /kaggle/input/age detection of actors/train/Train/11002.jpg
# /kaggle/input/age detection of actors/train/Train/7303.jpg
# /kaggle/input/age detection of actors/train/Train/19377.jpg
# /kaggle/input/age detection of actors/train/Train/15273.jpg
# /kaggle/input/age detection of actors/train/Train/16507.jpg
# /kaggle/input/age detection of actors/train/Train/797.jpg
# /kaggle/input/age detection of actors/train/Train/19983.jpg
# /kaggle/input/age detection of actors/train/Train/18468.jpg
# /kaggle/input/age detection of actors/train/Train/10165.jpg
# /kaggle/input/age detection of actors/train/Train/4869.jpg
# /kaggle/input/age detection of actors/train/Train/3444.jpg
# /kaggle/input/age detection of actors/train/Train/19710.jpg
# /kaggle/input/age detection of actors/train/Train/7853.jpg
# /kaggle/input/age detection of actors/train/Train/15646.jpg
# /kaggle/input/age detection of actors/train/Train/23913.jpg
# /kaggle/input/age detection of actors/train/Train/7878.jpg
# /kaggle/input/age detection of actors/train/Train/5533.jpg
# /kaggle/input/age detection of actors/train/Train/15940.jpg
# /kaggle/input/age detection of actors/train/Train/23025.jpg
# /kaggle/input/age detection of actors/train/Train/9354.jpg
# /kaggle/input/age detection of actors/train/Train/17078.jpg
# /kaggle/input/age detection of actors/train/Train/7318.jpg
# /kaggle/input/age detection of actors/train/Train/4846.jpg
# /kaggle/input/age detection of actors/train/Train/25020.jpg
# /kaggle/input/age detection of actors/train/Train/23604.jpg
# /kaggle/input/age detection of actors/train/Train/11511.jpg
# /kaggle/input/age detection of actors/train/Train/7290.jpg
# /kaggle/input/age detection of actors/train/Train/20565.jpg
# /kaggle/input/age detection of actors/train/Train/19436.jpg
# /kaggle/input/age detection of actors/train/Train/18712.jpg
# /kaggle/input/age detection of actors/train/Train/20291.jpg
# /kaggle/input/age detection of actors/train/Train/17724.jpg
# /kaggle/input/age detection of actors/train/Train/14874.jpg
# /kaggle/input/age detection of actors/train/Train/14648.jpg
# /kaggle/input/age detection of actors/train/Train/11330.jpg
# /kaggle/input/age detection of actors/train/Train/14018.jpg
# /kaggle/input/age detection of actors/train/Train/9983.jpg
# /kaggle/input/age detection of actors/train/Train/10742.jpg
# /kaggle/input/age detection of actors/train/Train/11958.jpg
# /kaggle/input/age detection of actors/train/Train/25455.jpg
# /kaggle/input/age detection of actors/train/Train/16097.jpg
# /kaggle/input/age detection of actors/train/Train/24066.jpg
# /kaggle/input/age detection of actors/train/Train/3106.jpg
# /kaggle/input/age detection of actors/train/Train/19687.jpg
# /kaggle/input/age detection of actors/train/Train/16145.jpg
# /kaggle/input/age detection of actors/train/Train/7828.jpg
# /kaggle/input/age detection of actors/train/Train/9992.jpg
# /kaggle/input/age detection of actors/train/Train/22745.jpg
# /kaggle/input/age detection of actors/train/Train/18337.jpg
# /kaggle/input/age detection of actors/train/Train/16292.jpg
# /kaggle/input/age detection of actors/train/Train/15467.jpg
# /kaggle/input/age detection of actors/train/Train/21824.jpg
# /kaggle/input/age detection of actors/train/Train/25559.jpg
# /kaggle/input/age detection of actors/train/Train/10092.jpg
# /kaggle/input/age detection of actors/train/Train/3497.jpg
# /kaggle/input/age detection of actors/train/Train/1498.jpg
# /kaggle/input/age detection of actors/train/Train/16444.jpg
# /kaggle/input/age detection of actors/train/Train/21487.jpg
# /kaggle/input/age detection of actors/train/Train/16818.jpg
# /kaggle/input/age detection of actors/train/Train/6741.jpg
# /kaggle/input/age detection of actors/train/Train/18779.jpg
# /kaggle/input/age detection of actors/train/Train/23354.jpg
# /kaggle/input/age detection of actors/train/Train/14003.jpg
# /kaggle/input/age detection of actors/train/Train/4008.jpg
# /kaggle/input/age detection of actors/train/Train/11199.jpg
# /kaggle/input/age detection of actors/train/Train/14880.jpg
# /kaggle/input/age detection of actors/train/Train/24791.jpg
# /kaggle/input/age detection of actors/train/Train/7544.jpg
# /kaggle/input/age detection of actors/train/Train/15197.jpg
# /kaggle/input/age detection of actors/train/Train/19617.jpg
# /kaggle/input/age detection of actors/train/Train/16783.jpg
# /kaggle/input/age detection of actors/train/Train/21130.jpg
# /kaggle/input/age detection of actors/train/Train/615.jpg
# /kaggle/input/age detection of actors/train/Train/22002.jpg
# /kaggle/input/age detection of actors/train/Train/8265.jpg
# /kaggle/input/age detection of actors/train/Train/8435.jpg
# /kaggle/input/age detection of actors/train/Train/20045.jpg
# /kaggle/input/age detection of actors/train/Train/4531.jpg
# /kaggle/input/age detection of actors/train/Train/14107.jpg
# /kaggle/input/age detection of actors/train/Train/10655.jpg
# /kaggle/input/age detection of actors/train/Train/21868.jpg
# /kaggle/input/age detection of actors/train/Train/922.jpg
# /kaggle/input/age detection of actors/train/Train/12318.jpg
# /kaggle/input/age detection of actors/train/Train/14017.jpg
# /kaggle/input/age detection of actors/train/Train/16817.jpg
# /kaggle/input/age detection of actors/train/Train/14277.jpg
# /kaggle/input/age detection of actors/train/Train/258.jpg
# /kaggle/input/age detection of actors/train/Train/24883.jpg
# /kaggle/input/age detection of actors/train/Train/6569.jpg
# /kaggle/input/age detection of actors/train/Train/19490.jpg
# /kaggle/input/age detection of actors/train/Train/3403.jpg
# /kaggle/input/age detection of actors/train/Train/23216.jpg
# /kaggle/input/age detection of actors/train/Train/7958.jpg
# /kaggle/input/age detection of actors/train/Train/19266.jpg
# /kaggle/input/age detection of actors/train/Train/26055.jpg
# /kaggle/input/age detection of actors/train/Train/6777.jpg
# /kaggle/input/age detection of actors/train/Train/10892.jpg
# /kaggle/input/age detection of actors/train/Train/16474.jpg
# /kaggle/input/age detection of actors/train/Train/25676.jpg
# /kaggle/input/age detection of actors/train/Train/26431.jpg
# /kaggle/input/age detection of actors/train/Train/7561.jpg
# /kaggle/input/age detection of actors/train/Train/2932.jpg
# /kaggle/input/age detection of actors/train/Train/710.jpg
# /kaggle/input/age detection of actors/train/Train/11505.jpg
# /kaggle/input/age detection of actors/train/Train/4502.jpg
# /kaggle/input/age detection of actors/train/Train/9668.jpg
# /kaggle/input/age detection of actors/train/Train/23778.jpg
# /kaggle/input/age detection of actors/train/Train/11922.jpg
# /kaggle/input/age detection of actors/train/Train/17760.jpg
# /kaggle/input/age detection of actors/train/Train/24768.jpg
# /kaggle/input/age detection of actors/train/Train/14381.jpg
# /kaggle/input/age detection of actors/train/Train/12155.jpg
# /kaggle/input/age detection of actors/train/Train/18786.jpg
# /kaggle/input/age detection of actors/train/Train/17744.jpg
# /kaggle/input/age detection of actors/train/Train/21309.jpg
# /kaggle/input/age detection of actors/train/Train/13356.jpg
# /kaggle/input/age detection of actors/train/Train/9642.jpg
# /kaggle/input/age detection of actors/train/Train/12601.jpg
# /kaggle/input/age detection of actors/train/Train/14221.jpg
# /kaggle/input/age detection of actors/train/Train/15156.jpg
# /kaggle/input/age detection of actors/train/Train/16708.jpg
# /kaggle/input/age detection of actors/train/Train/15076.jpg
# /kaggle/input/age detection of actors/train/Train/24306.jpg
# /kaggle/input/age detection of actors/train/Train/2522.jpg
# /kaggle/input/age detection of actors/train/Train/16674.jpg
# /kaggle/input/age detection of actors/train/Train/13868.jpg
# /kaggle/input/age detection of actors/train/Train/19601.jpg
# /kaggle/input/age detection of actors/train/Train/14631.jpg
# /kaggle/input/age detection of actors/train/Train/25706.jpg
# /kaggle/input/age detection of actors/train/Train/25029.jpg
# /kaggle/input/age detection of actors/train/Train/10769.jpg
# /kaggle/input/age detection of actors/train/Train/23789.jpg
# /kaggle/input/age detection of actors/train/Train/2043.jpg
# /kaggle/input/age detection of actors/train/Train/9311.jpg
# /kaggle/input/age detection of actors/train/Train/640.jpg
# /kaggle/input/age detection of actors/train/Train/19190.jpg
# /kaggle/input/age detection of actors/train/Train/3488.jpg
# /kaggle/input/age detection of actors/train/Train/5477.jpg
# /kaggle/input/age detection of actors/train/Train/10319.jpg
# /kaggle/input/age detection of actors/train/Train/26474.jpg
# /kaggle/input/age detection of actors/train/Train/9809.jpg
# /kaggle/input/age detection of actors/train/Train/6853.jpg
# /kaggle/input/age detection of actors/train/Train/2488.jpg
# /kaggle/input/age detection of actors/train/Train/24187.jpg
# /kaggle/input/age detection of actors/train/Train/5460.jpg
# /kaggle/input/age detection of actors/train/Train/8335.jpg
# /kaggle/input/age detection of actors/train/Train/19862.jpg
# /kaggle/input/age detection of actors/train/Train/926.jpg
# /kaggle/input/age detection of actors/train/Train/25203.jpg
# /kaggle/input/age detection of actors/train/Train/1013.jpg
# /kaggle/input/age detection of actors/train/Train/22006.jpg
# /kaggle/input/age detection of actors/train/Train/20868.jpg
# /kaggle/input/age detection of actors/train/Train/20741.jpg
# /kaggle/input/age detection of actors/train/Train/13833.jpg
# /kaggle/input/age detection of actors/train/Train/731.jpg
# /kaggle/input/age detection of actors/train/Train/15914.jpg
# /kaggle/input/age detection of actors/train/Train/26327.jpg
# /kaggle/input/age detection of actors/train/Train/23590.jpg
# /kaggle/input/age detection of actors/train/Train/15161.jpg
# /kaggle/input/age detection of actors/train/Train/22764.jpg
# /kaggle/input/age detection of actors/train/Train/18546.jpg
# /kaggle/input/age detection of actors/train/Train/7078.jpg
# /kaggle/input/age detection of actors/train/Train/15436.jpg
# /kaggle/input/age detection of actors/train/Train/22708.jpg
# /kaggle/input/age detection of actors/train/Train/10438.jpg
# /kaggle/input/age detection of actors/train/Train/20468.jpg
# /kaggle/input/age detection of actors/train/Train/22418.jpg
# /kaggle/input/age detection of actors/train/Train/6602.jpg
# /kaggle/input/age detection of actors/train/Train/2987.jpg
# /kaggle/input/age detection of actors/train/Train/3199.jpg
# /kaggle/input/age detection of actors/train/Train/3993.jpg
# /kaggle/input/age detection of actors/train/Train/6790.jpg
# /kaggle/input/age detection of actors/train/Train/13761.jpg
# /kaggle/input/age detection of actors/train/Train/21459.jpg
# /kaggle/input/age detection of actors/train/Train/547.jpg
# /kaggle/input/age detection of actors/train/Train/5940.jpg
# /kaggle/input/age detection of actors/train/Train/75.jpg
# /kaggle/input/age detection of actors/train/Train/3817.jpg
# /kaggle/input/age detection of actors/train/Train/11754.jpg
# /kaggle/input/age detection of actors/train/Train/6579.jpg
# /kaggle/input/age detection of actors/train/Train/16980.jpg
# /kaggle/input/age detection of actors/train/Train/17587.jpg
# /kaggle/input/age detection of actors/train/Train/24655.jpg
# /kaggle/input/age detection of actors/train/Train/16524.jpg
# /kaggle/input/age detection of actors/train/Train/23657.jpg
# /kaggle/input/age detection of actors/train/Train/21689.jpg
# /kaggle/input/age detection of actors/train/Train/18625.jpg
# /kaggle/input/age detection of actors/train/Train/12454.jpg
# /kaggle/input/age detection of actors/train/Train/4664.jpg
# /kaggle/input/age detection of actors/train/Train/10271.jpg
# /kaggle/input/age detection of actors/train/Train/9226.jpg
# /kaggle/input/age detection of actors/train/Train/6446.jpg
# /kaggle/input/age detection of actors/train/Train/19362.jpg
# /kaggle/input/age detection of actors/train/Train/16911.jpg
# /kaggle/input/age detection of actors/train/Train/1373.jpg
# /kaggle/input/age detection of actors/train/Train/6364.jpg
# /kaggle/input/age detection of actors/train/Train/12970.jpg
# /kaggle/input/age detection of actors/train/Train/26291.jpg
# /kaggle/input/age detection of actors/train/Train/864.jpg
# /kaggle/input/age detection of actors/train/Train/7497.jpg
# /kaggle/input/age detection of actors/train/Train/5368.jpg
# /kaggle/input/age detection of actors/train/Train/7304.jpg
# /kaggle/input/age detection of actors/train/Train/11929.jpg
# /kaggle/input/age detection of actors/train/Train/8809.jpg
# /kaggle/input/age detection of actors/train/Train/2637.jpg
# /kaggle/input/age detection of actors/train/Train/19345.jpg
# /kaggle/input/age detection of actors/train/Train/20549.jpg
# /kaggle/input/age detection of actors/train/Train/24205.jpg
# /kaggle/input/age detection of actors/train/Train/7877.jpg
# /kaggle/input/age detection of actors/train/Train/7996.jpg
# /kaggle/input/age detection of actors/train/Train/2137.jpg
# /kaggle/input/age detection of actors/train/Train/22363.jpg
# /kaggle/input/age detection of actors/train/Train/7758.jpg
# /kaggle/input/age detection of actors/train/Train/9980.jpg
# /kaggle/input/age detection of actors/train/Train/3750.jpg
# /kaggle/input/age detection of actors/train/Train/492.jpg
# /kaggle/input/age detection of actors/train/Train/22137.jpg
# /kaggle/input/age detection of actors/train/Train/1262.jpg
# /kaggle/input/age detection of actors/train/Train/12504.jpg
# /kaggle/input/age detection of actors/train/Train/25119.jpg
# /kaggle/input/age detection of actors/train/Train/18548.jpg
# /kaggle/input/age detection of actors/train/Train/21157.jpg
# /kaggle/input/age detection of actors/train/Train/209.jpg
# /kaggle/input/age detection of actors/train/Train/13259.jpg
# /kaggle/input/age detection of actors/train/Train/7135.jpg
# /kaggle/input/age detection of actors/train/Train/11721.jpg
# /kaggle/input/age detection of actors/train/Train/19768.jpg
# /kaggle/input/age detection of actors/train/Train/8456.jpg
# /kaggle/input/age detection of actors/train/Train/10676.jpg
# /kaggle/input/age detection of actors/train/Train/11234.jpg
# /kaggle/input/age detection of actors/train/Train/15787.jpg
# /kaggle/input/age detection of actors/train/Train/7122.jpg
# /kaggle/input/age detection of actors/train/Train/15263.jpg
# /kaggle/input/age detection of actors/train/Train/18477.jpg
# /kaggle/input/age detection of actors/train/Train/16854.jpg
# /kaggle/input/age detection of actors/train/Train/23488.jpg
# /kaggle/input/age detection of actors/train/Train/841.jpg
# /kaggle/input/age detection of actors/train/Train/17235.jpg
# /kaggle/input/age detection of actors/train/Train/6912.jpg
# /kaggle/input/age detection of actors/train/Train/6567.jpg
# /kaggle/input/age detection of actors/train/Train/18043.jpg
# /kaggle/input/age detection of actors/train/Train/772.jpg
# /kaggle/input/age detection of actors/train/Train/17048.jpg
# /kaggle/input/age detection of actors/train/Train/4026.jpg
# /kaggle/input/age detection of actors/train/Train/933.jpg
# /kaggle/input/age detection of actors/train/Train/16397.jpg
# /kaggle/input/age detection of actors/train/Train/3196.jpg
# /kaggle/input/age detection of actors/train/Train/4988.jpg
# /kaggle/input/age detection of actors/train/Train/2189.jpg
# /kaggle/input/age detection of actors/train/Train/4070.jpg
# /kaggle/input/age detection of actors/train/Train/2080.jpg
# /kaggle/input/age detection of actors/train/Train/4633.jpg
# /kaggle/input/age detection of actors/train/Train/12162.jpg
# /kaggle/input/age detection of actors/train/Train/11074.jpg
# /kaggle/input/age detection of actors/train/Train/14855.jpg
# /kaggle/input/age detection of actors/train/Train/969.jpg
# /kaggle/input/age detection of actors/train/Train/2396.jpg
# /kaggle/input/age detection of actors/train/Train/11686.jpg
# /kaggle/input/age detection of actors/train/Train/11155.jpg
# /kaggle/input/age detection of actors/train/Train/10179.jpg
# /kaggle/input/age detection of actors/train/Train/7876.jpg
# /kaggle/input/age detection of actors/train/Train/17115.jpg
# /kaggle/input/age detection of actors/train/Train/19479.jpg
# /kaggle/input/age detection of actors/train/Train/3485.jpg

# %%
import copy
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torchvision
from torchvision import models,transforms
import cv2
from tqdm import tqdm
import torch.nn as nn
from sklearn.model_selection import StratifiedKFold
import albumentations
import joblib

# %%
train_img_path = "../input/age detection of actors/train/Train"
train_df = pd.read_csv("../input/age detection of actors/train/train.csv")

test_img_path = "../input/age detection of actors/test/Test"
test_df = pd.read_csv("../input/age detection of actors/test/test.csv")

sub_df = pd.read_csv("../input/age detection of actors/sample_submission.csv")

# %%
train_df.Class.unique()
# Out:
# array(['MIDDLE', 'YOUNG', 'OLD'], dtype=object)

# %%
train_df["kfold"] = -1
kf = StratifiedKFold(n_splits = 5,shuffle=False,random_state=42)
train_df.sample(frac=1).reset_index(drop=True)

for fold_,(train_,val_) in enumerate(kf.split(X=train_df,y=train_df.Class.values)):
    train_df.loc[val_,"kfold"] = fold_
    print(len(train_),len(val_))
# Out:
# 15924 3982
# 15925 3981
# 15925 3981
# 15925 3981
# 15925 3981
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
train_df["kfold"].value_counts()
# Out:
# 0    3982
# 4    3981
# 3    3981
# 2    3981
# 1    3981
# Name: kfold, dtype: int64

# %%
for i in range(train_df.shape[0]):
    if train_df.loc[i,"Class"]=='YOUNG':
        train_df.loc[i,"Class"] = 0
    if train_df.loc[i,"Class"]=="MIDDLE":
        train_df.loc[i,"Class"] = 1
    if train_df.loc[i,"Class"]=="OLD":
        train_df.loc[i,"Class"] = 2

# %%
train_df.Class.unique()
# Out:
# array([1, 0, 2], dtype=object)

# %%
class ActorDataset:
    def __init__(self,image_list,target,aug=None,new_dim=None):
        self.image_list = image_list
        self.aug = aug
        self.target=target
        self.new_dim = new_dim
    
    def __len__(self):
        return len(self.image_list)
    
    def __getitem__(self,idx):
        
        image = self.image_list[idx]
        image = Image.open(image)
        if self.new_dim is not None:
            image = image.resize(self.new_dim)
        if self.aug is not None:
            image = self.aug(image=np.array(image))["image"]

        image = np.transpose(image, (2, 0, 1)).astype(np.float32)
        
        return {
            "image":torch.tensor(image,dtype=torch.float),
            "targets":torch.tensor(self.target[idx],dtype = torch.long)
        }

# %%
TRAIN_BATCH_SIZE = 16
VAL_BATCH_SIZE = 16
EPOCHS = 15
MODEL = "vgg"
NUM_CLASSES = 3
DEVICE ="cuda"

# %%
def set_parameters_grad(model,feature_extract = False):
    if feature_extract:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model,num_class,feature_extract=True,pretrained=True):
    
    model_ft = None
    input_size = 0
    
    if model == "resnet":
        model_ft = models.resnet50(pretrained = pretrained)
        set_parameters_grad(model_ft,feature_extract)
        num_ftrs = model.fc.in_features
        model_ft.fc = nn.linear(num_ftrs,num_class)
        input_size = (224,224)
    
    elif model == "vgg":
        model_ft = models.vgg11_bn(pretrained=pretrained)
        set_parameters_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,3)
        input_size = (224,224)
    
    elif model == "alexnet":
        model_ft = models.alexnet(pretrained=pretrained)
        set_parameters_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = (224,224)
    
    elif model == "densenet":
        self.model = models.densenet121(pretrained = pretrained)
        set_parameters_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_class)
        input_size = (224,224)
    
    elif model == "squeezenet":
        model_ft = models.squeezenet1_0(pretrained=pretrained)
        set_parameters_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_class, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_class
        input_size = (224,224)
    
    else:
        print("invalid model name")
    
    return model_ft,input_size

# %%
def train_model(model,dataloader,criterion,optimizer,device=DEVICE,epochs=5):
    val_acc_history = []
    best_model_weights = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    for epoch in range(epochs):
        print(f"EPOCH:{epoch}/{epochs-1}")
        print("-"*20)
        
        for phase in ["train","val"]:
            if phase == "train":
                model.train()
                bs = TRAIN_BATCH_SIZE
            else:
                model.val()
                bs = VAL_BATCH_SIZE
        
            running_loss = 0.0
            running_corrects = 0

            for i,batch in enumerate(dataloader[phase]):
                inputs = batch["image"]
                labels = batch["targets"]
                    
                if phase == "train":
                    optimizer.zero_grad()
                
                with torch.set_grad_enabled(phase == "train"):
                    outputs = model(inputs)
                    loss = criterion(outputs,labels)

                _, preds = torch.max(outputs, 1)

                if phase == "train":
                    loss.backward()
                    optimizer.step()

                running_corrects += torch.sum(preds == labels.data)
                accuracy = running_corrects.double() / len(dataloader[phase].dataset)

                print(f"{phase} LOSS:{loss} , {phase} ACC:{accuracy}")

            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)
        
    
    print('Best val Acc: {:4f}'.format(best_acc))
    
    model.load_state_dict(best_model_wts)
    return model,val_acc_history

# %%
def run(fold):
    train = train_df[train_df.kfold.values!=fold]
    val = train_df[train_df.kfold.values==fold]

    train_list = [os.path.join(train_img_path,train.ID.values[i]) for i in range(len(train.ID.values.tolist()))]
    val_list = [os.path.join(train_img_path,val.ID.values[i]) for i in range(len(val.ID.values.tolist()))]
    
    train_target = train.Class.values.tolist()
    val_target = val.Class.values.tolist()

    model_ft,input_size = initialize_model(MODEL,num_class = NUM_CLASSES,feature_extract=False,pretrained=True)
    
    train_aug = albumentations.Compose([
        albumentations.Normalize(mean = [0.485, 0.456, 0.406],std = [0.229, 0.224, 0.225]),
        albumentations.RGBShift(p=0.3),
        albumentations.RandomBrightnessContrast(p=0.3)
        
    ])
    
    train_dataset = ActorDataset(train_list,target=train_target,aug= train_aug,new_dim=input_size)

    val_aug = albumentations.Compose([
        albumentations.Normalize(mean = [0.485, 0.456, 0.406],std = [0.229, 0.224, 0.225])
    ])
    
    val_dataset = ActorDataset(val_list,target=val_target,aug= train_aug,new_dim=input_size)

    train_dataloader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size = TRAIN_BATCH_SIZE,
        shuffle = False,
        num_workers = 4

    )

    val_dataloader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size = VAL_BATCH_SIZE,
        shuffle = False,
        num_workers = 4

    )

    dataloader = {
        "train":train_dataloader,
        "val":val_dataloader
    }
    optimizer = torch.optim.SGD(model_ft.parameters(),lr = 3e-4, momentum = 0.9)
    lossfn = nn.CrossEntropyLoss()
    model,val_accuracy = train_model(model_ft,dataloader,criterion = lossfn,optimizer=optimizer,epochs=5)
    model_path = os.path.join("../input/output/fold_models",f"model_fold_{fold}.bin")
    torch.save(model.state_dict(), model_path)

# %%
os.mkdir("/kaggle/working/fold_models")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-15-326883e6aeb9> in <module>
# ----> 1 os.mkdir("/kaggle/working/fold_models")
#
# FileExistsError: [Errno 17] File exists: '/kaggle/working/fold_models'

# %%
if __name__=="__main__":
    run(0)
    run(1)
    run(2)
    run(3)
    run(4)
# Out:
# EPOCH:0/4
# --------------------
# train LOSS:1.3301843404769897 , train ACC:0.00012559658377292137
# train LOSS:1.3210899829864502 , train ACC:0.00025119316754584274
# train LOSS:1.2456531524658203 , train ACC:0.0004395880432052248
# train LOSS:1.1032596826553345 , train ACC:0.0009419743782969103
# train LOSS:1.117166519165039 , train ACC:0.001381562421502135
# train LOSS:1.1340818405151367 , train ACC:0.0017583521728208992
# train LOSS:1.1706844568252563 , train ACC:0.002072343632253203
# train LOSS:1.2667664289474487 , train ACC:0.0023235367997990453
# train LOSS:1.2627252340316772 , train ACC:0.0026375282592313487
# train LOSS:1.3690483570098877 , train ACC:0.002825923134890731
# train LOSS:1.2089523077011108 , train ACC:0.0030771163024365736
# train LOSS:0.9439181685447693 , train ACC:0.0035795026375282594
# train LOSS:1.189051628112793 , train ACC:0.003893494096960563
# train LOSS:1.1636407375335693 , train ACC:0.004144687264506406
# train LOSS:1.0846829414367676 , train ACC:0.004333082140165787
# train LOSS:0.98618084192276 , train ACC:0.0047726701833710125
# train LOSS:0.9971919655799866 , train ACC:0.005149459934689776
# train LOSS:1.0596940517425537 , train ACC:0.00546345139412208
# train LOSS:1.0226123332977295 , train ACC:0.005903039437327305
# train LOSS:0.9398845434188843 , train ACC:0.0063426274805325296
# train LOSS:0.9593141674995422 , train ACC:0.006845013815624215
# train LOSS:0.9527032375335693 , train ACC:0.007535795026375283
# train LOSS:0.8643336892127991 , train ACC:0.008226576237126351
# train LOSS:0.6030755043029785 , train ACC:0.00904295403165034
# train LOSS:0.9511945247650146 , train ACC:0.009419743782969104
# train LOSS:1.1097054481506348 , train ACC:0.009922130118060788
# train LOSS:0.9334433674812317 , train ACC:0.010298919869379553
# train LOSS:0.5708020329475403 , train ACC:0.011178095955790002
# train LOSS:0.9860645532608032 , train ACC:0.011680482290881688
# train LOSS:0.9712421894073486 , train ACC:0.012308465209746294
# train LOSS:1.1312848329544067 , train ACC:0.012685254961065059
# train LOSS:0.8013105988502502 , train ACC:0.013376036171816126
# train LOSS:0.9004616141319275 , train ACC:0.013941220798794273
# train LOSS:0.9543119668960571 , train ACC:0.014506405425772419
# train LOSS:0.8942484855651855 , train ACC:0.015071590052750565
# train LOSS:0.746863067150116 , train ACC:0.015825169555388093
# train LOSS:1.3386958837509155 , train ACC:0.016201959306706856
# train LOSS:1.1719454526901245 , train ACC:0.016767143933685003
# train LOSS:0.9254854321479797 , train ACC:0.01739512685254961
# train LOSS:1.1310412883758545 , train ACC:0.017897513187641295
# train LOSS:1.1681492328643799 , train ACC:0.0182115046470736
# train LOSS:0.9810571074485779 , train ACC:0.018713890982165284
# train LOSS:0.8428738117218018 , train ACC:0.01921627731725697
# train LOSS:0.9538625478744507 , train ACC:0.019781461944235117
# train LOSS:0.8271174430847168 , train ACC:0.020535041446872643
# train LOSS:0.7929213643074036 , train ACC:0.02097462949007787
# train LOSS:1.2645478248596191 , train ACC:0.021351419241396635
# train LOSS:1.2314010858535767 , train ACC:0.021665410700828936
# train LOSS:1.040561318397522 , train ACC:0.022293393619693545
# train LOSS:1.0327600240707397 , train ACC:0.02292137653855815
# train LOSS:0.9018346071243286 , train ACC:0.023486561165536296
# train LOSS:0.8386774063110352 , train ACC:0.024114544084400905
# train LOSS:0.9901559948921204 , train ACC:0.02474252700326551
# train LOSS:1.0052518844604492 , train ACC:0.025244913338357197
# train LOSS:0.9155400395393372 , train ACC:0.02574729967344888
# train LOSS:0.7726291418075562 , train ACC:0.02650087917608641

# %%
torch.cuda.is_available()
